# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from turtle import color
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [2], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from turtle import color
#
# File /usr/local/lib/python3.9/turtle.py:107
#     103 _ver = "turtle 1.1b- - for Python 3.1   -  4. 5. 2009"
#     105 # print(_ver)
# --> 107 import tkinter as TK
#     108 import types
#     109 import math
#
# File /usr/local/lib/python3.9/tkinter/__init__.py:37
#      34 import sys
#      35 import types
# ---> 37 import _tkinter # If this fails your Python may not be configured for Tk
#      38 TclError = _tkinter.TclError
#      39 from tkinter.constants import *
#
# ImportError: libtk8.6.so: cannot open shared object file: No such file or directory

# %%
plt.rcParams["figure.figsize"] = [12, 12]
plt.rcParams["axes.grid"] = True

# %%
dauer = pd.read_excel("events_mkw_kunst_gmbh_all_20221011-101037_20221018-101037.xlsx")
# Out:
# /root/.cache/pypoetry/virtualenvs/datascience-poetry-L7x8qOPX-py3.9/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# Histograme für die Stillbestände (Dauer der Stillstände)

# %%
dauer
# Out:
#      Name                      Start                        End  Dauer (s)  \
# 0    HL01   Oct 13, 2022, 7:23:47 PM   Oct 14, 2022, 9:47:52 AM      51845
# 1    HL01   Oct 13, 2022, 2:55:54 PM   Oct 13, 2022, 6:05:08 PM      11354
# 2    HL01   Oct 13, 2022, 9:14:38 AM   Oct 13, 2022, 1:00:43 PM      13565
# 3    HL01   Oct 12, 2022, 9:07:27 PM   Oct 13, 2022, 3:50:10 AM      24162
# 4    HL01   Oct 12, 2022, 7:42:00 AM   Oct 12, 2022, 7:55:20 AM        800
# ..    ...                        ...                        ...        ...
# 872  HL31   Oct 17, 2022, 8:35:12 AM   Oct 17, 2022, 8:38:04 AM        171
# 873  HL31  Oct 17, 2022, 11:36:01 AM  Oct 17, 2022, 11:49:43 AM        821
# 874  HL31   Oct 17, 2022, 7:55:23 PM   Oct 17, 2022, 8:09:15 PM        832
# 875  HL31   Oct 18, 2022, 4:26:48 AM   Oct 18, 2022, 4:36:41 AM        592
# 876  HL31   Oct 18, 2022, 7:56:56 AM   Oct 18, 2022, 8:05:25 AM        508
#
#     Ersteller-Typ     System-Kategorie  Benutzer-Kategorie
# ...

# %%
data_to_plot = dauer["Dauer (s)"]

# %%
ax = dauer['Dauer (s)'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Dauer')
ax.set_xlabel('sek')
# Out:
# Text(0.5, 0, 'sek')

# %%
# x = dauer['Dauer (s)'].plot(kind='hist', figsize=(14,6))
# ax.set_ylabel('Number of Dauer')
# ax.set_xlabel('sek')

# bins = [0,100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 7200]
bins = np.arange(start=0, stop=7201, step=60)
plt.hist(dauer['Dauer (s)'], bins= bins)
plt.ylabel("Anzahl der Stillstände")
plt.xlabel("Dauer in [s]")
plt.show()

# %%
from cProfile import label


bins = np.arange(start=0, stop=7201, step=60)
plt.hist(dauer['Dauer (s)'], bins= bins)
threshold = 600
color = '#fc4f30'
plt.axvline(threshold, color=color, label='10 min')
plt.ylabel("Anzahl der Stillstände")
plt.xlabel("Dauer in [s]")
plt.show()

# %%
#Wie viele unter 10 min.?
cond = dauer['Dauer (s)'] < 600
dauer[cond][:60]
# Out:
#     Name                      Start                        End  Dauer (s)  \
# 5   HL01  Oct 11, 2022, 10:02:03 AM  Oct 11, 2022, 10:06:53 AM        289
# 6   HL01   Oct 11, 2022, 9:43:20 PM   Oct 11, 2022, 9:48:18 PM        298
# 7   HL01   Oct 12, 2022, 3:04:45 AM   Oct 12, 2022, 3:06:48 AM        123
# 8   HL01   Oct 12, 2022, 5:54:54 PM   Oct 12, 2022, 6:04:44 PM        589
# 9   HL01   Oct 13, 2022, 7:40:40 AM   Oct 13, 2022, 7:46:21 AM        341
# 10  HL01   Oct 13, 2022, 1:32:21 PM   Oct 13, 2022, 1:33:57 PM         95
# 11  HL01   Oct 13, 2022, 1:39:55 PM   Oct 13, 2022, 1:42:50 PM        174
# 12  HL01   Oct 13, 2022, 1:43:54 PM   Oct 13, 2022, 1:45:22 PM         88
# 13  HL01   Oct 13, 2022, 1:46:12 PM   Oct 13, 2022, 1:47:32 PM         80
# 14  HL01   Oct 13, 2022, 6:05:47 PM   Oct 13, 2022, 6:12:59 PM        431
# 16  HL01   Oct 13, 2022, 6:54:38 PM   Oct 13, 2022, 6:59:26 PM        287
# 17  HL01   Oct 13, 2022, 7:12:06 PM   Oct 13, 2022, 7:15:52 PM        225
# ...

# %%
#Wie viele über 10 min.?
cond = dauer['Dauer (s)'] > 600
dauer[cond][:60]
# Out:
#      Name                      Start                        End  Dauer (s)  \
# 0    HL01   Oct 13, 2022, 7:23:47 PM   Oct 14, 2022, 9:47:52 AM      51845
# 1    HL01   Oct 13, 2022, 2:55:54 PM   Oct 13, 2022, 6:05:08 PM      11354
# 2    HL01   Oct 13, 2022, 9:14:38 AM   Oct 13, 2022, 1:00:43 PM      13565
# 3    HL01   Oct 12, 2022, 9:07:27 PM   Oct 13, 2022, 3:50:10 AM      24162
# 4    HL01   Oct 12, 2022, 7:42:00 AM   Oct 12, 2022, 7:55:20 AM        800
# 15   HL01   Oct 13, 2022, 6:13:38 PM   Oct 13, 2022, 6:53:49 PM       2411
# 21   HL01  Oct 15, 2022, 12:08:05 AM   Oct 17, 2022, 3:58:21 AM     186615
# 22   HL01   Oct 17, 2022, 4:12:29 AM   Oct 17, 2022, 4:23:35 AM        665
# 26   HL02   Oct 17, 2022, 3:41:51 PM   Oct 17, 2022, 4:07:48 PM       1556
# 27   HL02   Oct 17, 2022, 3:20:52 PM   Oct 17, 2022, 3:32:43 PM        710
# 28   HL02   Oct 13, 2022, 4:50:52 PM   Oct 13, 2022, 5:46:57 PM       3364
# ...
